# %% [markdown]
# Using ladder position previous and current

# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("data/train.csv")

training_data = df.dropna(subset = ['Ladder_Position_Prev', 'Ladder_Position', 'Ladder_Position_Next'])
x = training_data[['Ladder_Position_Prev', 'Ladder_Position']]
y = training_data['Ladder_Position_Next']

model = LinearRegression()
model.fit(x,y)
print("Coefficient for Ladder_Position_Prev:", model.coef_[0])
print("Coefficient for Ladder_Position:", model.coef_[1])
print("Intercept:", model.intercept_)
print("R^2 Score:", model.score(x, y))

y_pred = model.predict(x)

plt.scatter(y, y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # Diagonal reference line
plt.xlabel("Actual Ladder_Position_Next")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted Ladder Position (Next Year)")
plt.grid(True)
plt.show()
# Out:
# Coefficient for Ladder_Position_Prev: 0.16679975521146173
# Coefficient for Ladder_Position: 0.45642639598981105
# Intercept: 2.692833145933588
# R^2 Score: 0.3212252301037315

# %% [markdown]
# For all of the stats

# %%
import statsmodels.api as sm

x_const = sm.add_constant(x)

model = sm.OLS(y, x_const).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Ladder_Position_Next   R-squared:                       0.321
# Model:                              OLS   Adj. R-squared:                  0.320
# Method:                   Least Squares   F-statistic:                     256.3
# Date:                  Sat, 03 May 2025   Prob (F-statistic):           7.58e-92
# Time:                          12:28:16   Log-Likelihood:                -2858.4
# No. Observations:                  1086   AIC:                             5723.
# Df Residuals:                      1083   BIC:                             5738.
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.6928      0.221     12.188      0.000       2.259       3.126
# ...

# %% [markdown]
# Using ladder previous current and percentage

# %%
training_data = df.dropna(subset = ['Percentage', 'Ladder_Position', 'Ladder_Position_Next'])
x = training_data[['Percentage', 'Ladder_Position']]
y = training_data['Ladder_Position_Next']

model = LinearRegression()
model.fit(x,y)
print("Coefficient for Percentage:", model.coef_[0])
print("Coefficient for Ladder_Position:", model.coef_[1])
print("Intercept:", model.intercept_)
print("R^2 Score:", model.score(x, y))

y_pred = model.predict(x)

plt.scatter(y, y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # Diagonal reference line
plt.xlabel("Actual Ladder_Position_Next")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted Ladder Position (Next Year)")
plt.grid(True)
plt.show()
# Out:
# Coefficient for Percentage: -0.025357390614835357
# Coefficient for Ladder_Position: 0.44101865262457407
# Intercept: 6.612911395219921
# R^2 Score: 0.31613952384288924

# %% [markdown]
# for all stats

# %%
x_const = sm.add_constant(x)

model = sm.OLS(y, x_const).fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Ladder_Position_Next   R-squared:                       0.316
# Model:                              OLS   Adj. R-squared:                  0.315
# Method:                   Least Squares   F-statistic:                     254.3
# Date:                  Sat, 03 May 2025   Prob (F-statistic):           1.71e-91
# Time:                          12:28:16   Log-Likelihood:                -2909.0
# No. Observations:                  1103   AIC:                             5824.
# Df Residuals:                      1100   BIC:                             5839.
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               6.6129      0.984      6.722      0.000       4.683       8.543
# ...
